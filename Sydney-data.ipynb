# %%
import csv 
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
with open('GlobalLandTemperaturesByCity.csv') as csvfile:
    data = pd.read_csv(csvfile)
    #wrangling some data to get only one city
    changedata = data[data['City'].str.match('Sydney') & data['Country'].str.match('Australia')]
    #changedata = changedata.set_index(changedata['dt'])
    #changedata = changedata['dt'].to_datetime()
    usedata = changedata[changedata['dt']>= '1900-01-01']
    print(usedata)
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 7294862  1900-01-01              19.999                          1.023
# 7294863  1900-02-01              20.734                          1.525
# 7294864  1900-03-01              19.960                          0.499
# 7294865  1900-04-01              17.228                          0.561
# 7294866  1900-05-01              15.741                          0.630
# ...             ...                 ...                            ...
# 7296222  2013-05-01              16.947                          0.154
# 7296223  2013-06-01              15.911                          0.176
# 7296224  2013-07-01              15.518                          0.178
# 7296225  2013-08-01              16.126                          0.325
# 7296226  2013-09-01                 NaN                            NaN
#
#            City    Country Latitude Longitude
# 7294862  Sydney  Australia   34.56S   151.78E
# 7294863  Sydney  Australia   34.56S   151.78E
# 7294864  Sydney  Australia   34.56S   151.78E
# 7294865  Sydney  Australia   34.56S   151.78E
# 7294866  Sydney  Australia   34.56S   151.78E
# ...         ...        ...      ...       ...
# 7296222  Sydney  Australia   34.56S   151.78E
# 7296223  Sydney  Australia   34.56S   151.78E
# 7296224  Sydney  Australia   34.56S   151.78E
# 7296225  Sydney  Australia   34.56S   151.78E
# 7296226  Sydney  Australia   34.56S   151.78E
#
# [1365 rows x 7 columns]

# %%
#getting one data point per year

#dtu = pd.date_range('2000-01-01', '2010-01-01')
#df = pd.DataFrame(range(len(dtu)), index=dtu)

#df.resample('1y').agg([min, max])
#print(df)

# %%
x = usedata['dt']
y = usedata['AverageTemperature']
plt.figure(figsize=(20,20))
plt.scatter(x,y,) 
plt.yscale('linear')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.bar(x,y)
plt.show()
