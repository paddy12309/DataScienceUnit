# %%
import csv 
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
with open('GlobalLandTemperaturesByCity.csv') as csvfile:
    data = pd.read_csv(csvfile)
    #wrangling some data to get only one city
    changedata = data[data['City'].str.match('Pokhara') & data['Country'].str.match('Nepal')]
    #changedata = changedata.set_index(changedata['dt'])
    #changedata = changedata['dt'].to_datetime()
    usedata = changedata[changedata['dt']>= '1900-01-01']
    print(usedata)
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 5944044  1900-01-01               5.914                          0.623
# 5944045  1900-02-01               7.745                          0.567
# 5944046  1900-03-01              13.269                          0.654
# 5944047  1900-04-01              16.440                          0.571
# 5944048  1900-05-01              18.661                          0.399
# ...             ...                 ...                            ...
# 5945404  2013-05-01              20.069                          0.719
# 5945405  2013-06-01              21.168                          0.407
# 5945406  2013-07-01              21.503                          0.316
# 5945407  2013-08-01              21.541                          0.478
# 5945408  2013-09-01                 NaN                            NaN
#
#             City Country Latitude Longitude
# 5944044  Pokhara   Nepal   28.13N    84.55E
# 5944045  Pokhara   Nepal   28.13N    84.55E
# 5944046  Pokhara   Nepal   28.13N    84.55E
# 5944047  Pokhara   Nepal   28.13N    84.55E
# 5944048  Pokhara   Nepal   28.13N    84.55E
# ...          ...     ...      ...       ...
# 5945404  Pokhara   Nepal   28.13N    84.55E
# 5945405  Pokhara   Nepal   28.13N    84.55E
# 5945406  Pokhara   Nepal   28.13N    84.55E
# 5945407  Pokhara   Nepal   28.13N    84.55E
# 5945408  Pokhara   Nepal   28.13N    84.55E
#
# [1365 rows x 7 columns]

# %%
#getting one data point per year

#dtu = pd.date_range('2000-01-01', '2010-01-01')
#df = pd.DataFrame(range(len(dtu)), index=dtu)

#df.resample('1y').agg([min, max])
#print(df)

# %%
x = usedata['dt']
y = usedata['AverageTemperature']
plt.figure(figsize=(10,10))
plt.scatter(x,y,) 
plt.yscale('linear')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.bar(x,y)
plt.show()
